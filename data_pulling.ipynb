# %% [markdown]
# Dictionary
# 1. Private Domestic
# 2. Private Office
# 3. Private Retail
# 4. Private Flatted Factory
#
# 1 = Rent
# 2 = Price
# (Case-by-case)
# 3 = Rental indicies by grade
# 4 = Price indicies by grade

# %%
import pandas as pd

urls = {"realResidential":"https://stats.bis.org/api/v2/data/dataflow/BIS/WS_SPP/1.0/Q.HK.R.628?format=csv",
        "nominalResidential":"https://stats.bis.org/api/v2/data/dataflow/BIS/WS_SPP/1.0/Q.HK.N.628?format=csv",
        "existingResidentialM":"https://stats.bis.org/api/v2/data/dataflow/BIS/WS_DPP/1.0/M.HK.0.1.0.1.1.0?format=csv",
        "existingResidentialQ":"https://stats.bis.org/api/v2/data/dataflow/BIS/WS_DPP/1.0/Q.HK.0.1.0.1.1.0?format=csv"}

# df = pd.concat([pd.read_csv(url) for title, url in urls.items])

# %%
for title, url in urls.items():
    print(title, url)
# Out:
# realResidential https://stats.bis.org/api/v2/data/dataflow/BIS/WS_SPP/1.0/Q.HK.R.628?format=csv
# nominalResidential https://stats.bis.org/api/v2/data/dataflow/BIS/WS_SPP/1.0/Q.HK.N.628?format=csv
# existingResidentialM https://stats.bis.org/api/v2/data/dataflow/BIS/WS_DPP/1.0/M.HK.0.1.0.1.1.0?format=csv
# existingResidentialQ https://stats.bis.org/api/v2/data/dataflow/BIS/WS_DPP/1.0/Q.HK.0.1.0.1.1.0?format=csv

# %%
df_realResidential = pd.concat([pd.read_csv(urls['realResidential'])])
df_realResidential
# Out:
#     FREQ REF_AREA VALUE  UNIT_MEASURE  UNIT_MULT  BREAKS  COVERAGE  TITLE_TS
# 0      Q       HK     R           628          0     NaN       NaN       NaN  \
# 1      Q       HK     R           628          0     NaN       NaN       NaN
# 2      Q       HK     R           628          0     NaN       NaN       NaN
# 3      Q       HK     R           628          0     NaN       NaN       NaN
# 4      Q       HK     R           628          0     NaN       NaN       NaN
# ..   ...      ...   ...           ...        ...     ...       ...       ...
# 176    Q       HK     R           628          0     NaN       NaN       NaN
# 177    Q       HK     R           628          0     NaN       NaN       NaN
# 178    Q       HK     R           628          0     NaN       NaN       NaN
# 179    Q       HK     R           628          0     NaN       NaN       NaN
# 180    Q       HK     R           628          0     NaN       NaN       NaN
#
# ...
